# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset= pd.read_csv('kc_house_data.csv')

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
price= dataset['price']

# %%
price.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
x= dataset['sqft_living']

# %%
print(x)
# Out:
# 0        1180
# 1        2570
# 2         770
# 3        1960
# 4        1680
# 5        5420
# 6        1715
# 7        1060
# 8        1780
# 9        1890
# 10       3560
# 11       1160
# 12       1430
# 13       1370
# 14       1810
# 15       2950
# 16       1890
# 17       1600
# 18       1200
# 19       1250
# 20       1620
# 21       3050
# 22       2270
# 23       1070
# 24       2450
# 25       1710
# 26       2450
# 27       1400
# 28       1520
# 29       2570
#          ...
# 21583     710
# 21584    1260
# 21585    1870
# 21586    1430
# 21587    1520
# 21588    1210
# 21589    2540
# 21590    4910
# 21591    2770
# 21592    1190
# 21593    4170
# 21594    2500
# 21595    1530
# 21596    3600
# 21597    3410
# 21598    3118
# 21599    3990
# 21600    4470
# 21601    1425
# 21602    1500
# 21603    2270
# 21604    1490
# 21605    2520
# 21606    3510
# 21607    1310
# 21608    1530
# 21609    2310
# 21610    1020
# 21611    1600
# 21612    1020
# ...

# %%
plt.plot(price,x,'ro')

# %%
import tensorflow as tf

slope = tf.Variable(0.0)
intercept = tf.Variable(0.0)
sqliv =tf.placeholder(tf.float32)

#linear model

predicted_value = intercept + slope*sqliv

actual_value = tf.placeholder(tf.float32)

#loss

loss = tf.reduce_mean(tf.square(predicted_value - actual_value))

# %%
optimizer = tf.train.GradientDescentOptimizer(0.0000001) # inside is the learning rate/ step


train= optimizer.minimize(loss) #create a tensor.

# %%
sess = tf.Session()
init= tf.global_variables_initializer()
sess.run(init)

# %%
for i in range(10000): # expirementation here this is the iterations. 
    data = {sqliv: x, actual_value: price}# load the data
    sess.run(train, feed_dict = data)
    
    # to know what is happening
    
    c_slope, c_intercept, c_loss = sess.run([slope,intercept, loss],feed_dict=data)
    print("Slope: %s, intercept: %s, cost:%s"%(c_slope, c_intercept, c_loss))
# Out:
# Slope: 272.007, intercept: 0.108018, cost:6.90722e+10
# Slope: 262.787, intercept: 0.102886, cost:6.86617e+10
# Slope: 263.099, intercept: 0.101589, cost:6.86612e+10
# Slope: 263.089, intercept: 0.100163, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0987408, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0973186, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0958964, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0944742, cost:6.86611e+10
# Slope: 263.089, intercept: 0.093052, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0916298, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0902076, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0887854, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0873632, cost:6.86611e+10
# Slope: 263.089, intercept: 0.085941, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0845188, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0830966, cost:6.86611e+10
# Slope: 263.089, intercept: 0.0816744, cost:6.86611e+10
# ...
